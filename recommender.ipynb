# %%
import pandas as pd
import numpy as np
from scipy import sparse
import seaborn as sns
import matplotlib.pyplot as plt
import sys

from sklearn.metrics.pairwise import pairwise_distances, cosine_distances, cosine_similarity

pd.set_option('display.max_colwidth', None)

# %%
# read in board game ratings
df = pd.read_csv('./data/bgg-15m-reviews.csv', index_col = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15823269 entries, 0 to 15823268
# Data columns (total 5 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user     object
#  1   rating   float64
#  2   comment  object
#  3   ID       int64
#  4   name     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 724.3+ MB

# %%
df[df['name'].str.contains('Pandemic')]['name'].value_counts()
# Out:
# Pandemic                              96234
# Pandemic Legacy: Season 1             38376
# Pandemic Legacy: Season 2             10614
# Pandemic: The Cure                     8941
# Pandemic: Iberia                       7775
# Pandemic: Reign of Cthulhu             7265
# Pandemic: Fall of Rome                 3213
# Pandemic: Contagion                    2997
# Pandemic: Rising Tide                  1845
# Pandemic: Rapid Response               1325
# Pandemic: Hot Zone – North America      238
# Pandemic Legacy: Season 0                98
# Name: name, dtype: int64

# %%
df.shape
# Out:
# (15823269, 5)

# %%
df.drop(columns = ['comment', 'ID'], inplace = True)

# %%
df.user.nunique()
# Out:
# 351048

# %%
df.name.nunique()
# Out:
# 18984

# %%
counts = df.groupby('name')['rating'].count()

# %%
users = df.groupby('user')['rating'].count()

# %%
users = pd.DataFrame(users)

# %%
counts = pd.DataFrame(counts)

# %%
users.rename(columns = {'rating': 'user_review_count'}, inplace = True)

# %%
counts.rename(columns = {'rating': 'game_review_count'}, inplace = True)

# %%
df_counts = df.join(users, on = 'user')

# %%
df_counts = df_counts.join(counts, on = 'name')

# %%
df_counts.head()
# Out:
#               user  rating      name  user_review_count  game_review_count
# 0          Torsten    10.0  Pandemic             1358.0              96234
# 1  mitnachtKAUBO-I    10.0  Pandemic              395.0              96234
# 2           avlawn    10.0  Pandemic             1036.0              96234
# 3       Mike Mayer    10.0  Pandemic              716.0              96234
# 4          Mease19    10.0  Pandemic              379.0              96234

# %%
df_counts.shape
# Out:
# (15823269, 4)

# %%
reduced_df = df_counts[(df_counts['game_review_count'] > 2000) & (df_counts['user_review_count'] >= 10)]

# %%
reduced_df.shape
# Out:
# (10954903, 5)

# %%
reduced_df['name'].nunique()
# Out:
# 1424

# %%
reduced_df['user'].nunique()
# Out:
# 191706

# %%
piv_df = pd.pivot_table(reduced_df, index = 'name', columns='user', values='rating')

# %%
piv_df.head()
# Out:
# user                                mycroft  -=Yod@=-  -Johnny-  -Loren-  \
# name
# 13 Days: The Cuban Missile Crisis       NaN       NaN       NaN      NaN
# 1775: Rebellion                         NaN       NaN       NaN      NaN
# 1812: The Invasion of Canada            NaN       NaN       8.0      NaN
# 1830: Railways & Robber Barons          NaN       NaN       4.0      NaN
# 1960: The Making of the President       NaN       NaN       6.0      NaN
#
# user                               -LucaS-  -mIDE-  -mik-  -pj-  -snarf-  \
# name
# 13 Days: The Cuban Missile Crisis      NaN     NaN    NaN   NaN      NaN
# 1775: Rebellion                        NaN     NaN    NaN   NaN      NaN
# 1812: The Invasion of Canada           NaN     NaN    NaN   NaN      NaN
# 1830: Railways & Robber Barons         NaN     NaN    NaN   NaN      NaN
# 1960: The Making of the President      NaN     8.5    NaN   NaN      NaN
#
# user                               -toni-  ...  zzz2525  zzzabiss  zzzeagle  \
# name                                       ...
# 13 Days: The Cuban Missile Crisis     NaN  ...      NaN       NaN       NaN
# 1775: Rebellion                       NaN  ...      NaN       NaN       NaN
# 1812: The Invasion of Canada          NaN  ...      NaN       NaN       NaN
# 1830: Railways & Robber Barons        NaN  ...      NaN       NaN       NaN
# 1960: The Making of the President     NaN  ...      NaN       NaN       NaN
#
# user                               zzzk1  zzzkardel  zzzuzu  zzzvone  \
# name
# 13 Days: The Cuban Missile Crisis    NaN        NaN     NaN      NaN
# 1775: Rebellion                      NaN        NaN     NaN      NaN
# 1812: The Invasion of Canada         NaN        NaN     NaN      NaN
# 1830: Railways & Robber Barons       NaN        NaN     NaN      NaN
# 1960: The Making of the President    NaN        NaN     NaN      NaN
#
# user                               zzzxxxyyy  zzzzzane  Æleksandr Þræð
# name
# 13 Days: The Cuban Missile Crisis        NaN       NaN             NaN
# 1775: Rebellion                          NaN       NaN             NaN
# 1812: The Invasion of Canada             NaN       NaN             NaN
# 1830: Railways & Robber Barons           NaN       NaN             NaN
# 1960: The Making of the President        NaN       NaN             NaN
#
# [5 rows x 191706 columns]

# %%
piv_df.info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1424 entries, 13 Days: The Cuban Missile Crisis to ZÈRTZ
# Columns: 191706 entries,  mycroft to Æleksandr Þræð
# dtypes: float64(191706)
# memory usage: 2.0+ GB

# %%
sparse_df = sparse.csr_matrix(piv_df.fillna(0))

# %%
recommender = pairwise_distances(sparse_df, metric = 'cosine')

# %%
rec_df = pd.DataFrame(recommender, columns = piv_df.index, index = piv_df.index)

# %%
rec_df.head()
# Out:
# name                               13 Days: The Cuban Missile Crisis  \
# name
# 13 Days: The Cuban Missile Crisis                           0.000000
# 1775: Rebellion                                             0.811559
# 1812: The Invasion of Canada                                0.868826
# 1830: Railways & Robber Barons                              0.901087
# 1960: The Making of the President                           0.811312
#
# name                               1775: Rebellion  \
# name
# 13 Days: The Cuban Missile Crisis         0.811559
# 1775: Rebellion                           0.000000
# 1812: The Invasion of Canada              0.671585
# 1830: Railways & Robber Barons            0.899418
# 1960: The Making of the President         0.816623
#
# name                               1812: The Invasion of Canada  \
# name
# 13 Days: The Cuban Missile Crisis                      0.868826
# 1775: Rebellion                                        0.671585
# 1812: The Invasion of Canada                           0.000000
# 1830: Railways & Robber Barons                         0.895324
# 1960: The Making of the President                      0.827162
#
# name                               1830: Railways & Robber Barons  \
# name
# 13 Days: The Cuban Missile Crisis                        0.901087
# 1775: Rebellion                                          0.899418
# 1812: The Invasion of Canada                             0.895324
# 1830: Railways & Robber Barons                           0.000000
# 1960: The Making of the President                        0.818172
#
# name                               1960: The Making of the President  \
# name
# 13 Days: The Cuban Missile Crisis                           0.811312
# 1775: Rebellion                                             0.816623
# 1812: The Invasion of Canada                                0.827162
# 1830: Railways & Robber Barons                              0.818172
# 1960: The Making of the President                           0.000000
#
# name                               221B Baker Street: The Master Detective Game  \
# name
# %%
1 - rec_df['XCOM: The Board Game'].sort_values()[:11]
# Out:
# name
# XCOM: The Board Game                                 1.000000
# Dead of Winter: A Crossroads Game                    0.255387
# Battlestar Galactica: The Board Game                 0.241412
# Star Wars: Imperial Assault                          0.229693
# Star Wars: Rebellion                                 0.224869
# Eldritch Horror                                      0.222351
# T.I.M.E Stories                                      0.220177
# Robinson Crusoe: Adventures on the Cursed Island     0.218207
# Legendary Encounters: An Alien Deck Building Game    0.216495
# Mansions of Madness: Second Edition                  0.214675
# Lords of Waterdeep                                   0.213760
# Name: XCOM: The Board Game, dtype: float64

# %%
rec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1424 entries, 13 Days: The Cuban Missile Crisis to ZÈRTZ
# Columns: 1424 entries, 13 Days: The Cuban Missile Crisis to ZÈRTZ
# dtypes: float64(1424)
# memory usage: 15.5+ MB

# %%
rec_df.to_csv('./data/rec_df.csv')

# %%
info_df = pd.read_csv('./data/games_detailed_info.csv')

# %%
info_df.drop(columns=['Unnamed: 0', 'id', 'alternate', 'image', 'description', 'suggested_language_dependence', 'minplaytime', 'maxplaytime', 
                     'minage', 'boardgamefamily', 'boardgameexpansion', 'boardgameimplementation',
       'boardgamedesigner', 'boardgameartist', 'boardgamepublisher', 'usersrated', 'bayesaverage', 'Board Game Rank',
       'Strategy Game Rank', 'Family Game Rank', 'stddev', 'median', 'owned',
       'trading', 'wanting', 'wishing', 'numcomments', 'numweights',
       'averageweight', 'boardgameintegration', 'boardgamecompilation',
       'Party Game Rank', 'Abstract Game Rank', 'Thematic Rank',
       'War Game Rank', 'Customizable Rank', "Children's Game Rank",
       'RPG Item Rank', 'Accessory Rank', 'Video Game Rank', 'Amiga Rank',
       'Commodore 64 Rank', 'Arcade Rank', 'Atari ST Rank', 'suggested_num_players', 'suggested_playerage', 'type'], inplace=True)

# %%
info_df.rename(columns={'primary': 'name', 'thumbnail': 'Thumbnail', 'yearpublished': 'Year Published', 'minplayers': 'Min Players', 'maxplayers': 'Max Players',
                       'playingtime': 'Play Time (Minutes)', 'boardgamecategory': 'Category', 'boardgamemechanic': 'Mechanics', 'average': 'Average Rating'}, inplace = True)

# %%
info_df.set_index('name', inplace=True)

# %%
info_df['Average Rating'] = info_df['Average Rating'] / 10

# %%
info_df.head()
# Out:
#                                                                                                      Thumbnail  \
# name
# Pandemic     https://cf.geekdo-images.com/thumb/img/HEKrtpTC1y1amXh5cKnVvowyE5Y=/fit-in/200x150/pic1534148.jpg
# Carcassonne  https://cf.geekdo-images.com/thumb/img/kqE4YJSm5PVkocYGl-V_IJcZQw4=/fit-in/200x150/pic2337577.jpg
# Catan        https://cf.geekdo-images.com/thumb/img/g8LvJsd2oLAub6AEKN_Xpdoi8Sw=/fit-in/200x150/pic2419375.jpg
# 7 Wonders     https://cf.geekdo-images.com/thumb/img/Grz-qM9xwxlvQGK7B-MiljtO9pQ=/fit-in/200x150/pic860217.jpg
# Dominion      https://cf.geekdo-images.com/thumb/img/iPlTR5cXFGrDuhupUgWGPjFjDPo=/fit-in/200x150/pic394356.jpg
#
#              Year Published  Min Players  Max Players  Play Time (Minutes)  \
# name
# Pandemic               2008            2            4                   45
# Carcassonne            2000            2            5                   45
# Catan                  1995            3            4                  120
# 7 Wonders              2010            2            7                   30
# Dominion               2008            2            4                   30
#
#                                                                           Category  \
# name
# Pandemic                                                               ['Medical']
# Carcassonne                    ['City Building', 'Medieval', 'Territory Building']
# Catan                                                  ['Economic', 'Negotiation']
# 7 Wonders    ['Ancient', 'Card Game', 'City Building', 'Civilization', 'Economic']
# Dominion                                                 ['Card Game', 'Medieval']
#
#                                                                                                                                                        Mechanics  \
# name
# Pandemic              ['Action Points', 'Cooperative Game', 'Hand Management', 'Point to Point Movement', 'Set Collection', 'Trading', 'Variable Player Powers']
# Carcassonne                                                                                      ['Area Majority / Influence', 'Map Addition', 'Tile Placement']
# Catan        ['Dice Rolling', 'Hexagon Grid', 'Income', 'Modular Board', 'Network and Route Building', 'Race', 'Random Production', 'Trading', 'Variable Setup']
# 7 Wonders                          ['Card Drafting', 'Drafting', 'Hand Management', 'Set Collection', 'Simultaneous Action Selection', 'Variable Player Powers']
# Dominion                                                  ['Deck, Bag, and Pool Building', 'Delayed Purchase', 'Hand Management', 'Take That', 'Variable Setup']
#
#              Average Rating
# name
# Pandemic           0.761567
# Carcassonne        0.741884
# Catan              0.716265
# 7 Wonders          0.776049
# Dominion           0.762671

# %%
info_df.to_csv('./data/info_df.csv')

# %%
temp_df = 1 - rec_df['Spartacus: A Game of Blood and Treachery'].sort_values()[1:11]

# %%
temp_df = pd.DataFrame(temp_df)

# %%
temp_df.rename(columns={'Spartacus: A Game of Blood and Treachery': 'Score'}, inplace = True)

# %%
temp_df.columns
# Out:
# Index(['Score'], dtype='object')

# %%
temp_df.head()
# Out:
#                                                        Score
# name
# Battlestar Galactica: The Board Game                0.238424
# A Game of Thrones: The Board Game (Second Edition)  0.236198
# Cyclades                                            0.233905
# Chaos in the Old World                              0.231561
# Blood Bowl: Team Manager – The Card Game            0.217015

# %%
temp_df.join(info_df)
# Out:
#                                                        Score  \
# name
# A Game of Thrones: The Board Game (Second Edition)  0.236198
# Battlestar Galactica: The Board Game                0.238424
# Blood Bowl: Team Manager – The Card Game            0.217015
# Blood Rage                                          0.209887
# Chaos in the Old World                              0.231561
# Cyclades                                            0.233905
# Dead of Winter: A Crossroads Game                   0.206986
# Kemet                                               0.209070
# Merchants & Marauders                               0.209446
# Sons of Anarchy: Men of Mayhem                      0.209623
#
#                                                                                                                                             Thumbnail  \
# name
# A Game of Thrones: The Board Game (Second Edition)  https://cf.geekdo-images.com/thumb/img/jKVCyVKboWKMpLlI9pB9ojeqM_w=/fit-in/200x150/pic1077906.jpg
# Battlestar Galactica: The Board Game                 https://cf.geekdo-images.com/thumb/img/NpZjJd2NgxSJV2WrlB_U1e89txY=/fit-in/200x150/pic354500.jpg
# Blood Bowl: Team Manager – The Card Game            https://cf.geekdo-images.com/thumb/img/t1fhkbVdnXttA2WZJl9OO8RtbHk=/fit-in/200x150/pic1222746.jpg
# Dead of Winter: A Crossroads Game                                                                                                       ['Bluffing', 'Deduction', 'Horror', 'Zombies']
# Kemet                                                                                                                    ['Ancient', 'Fighting', 'Miniatures', 'Mythology', 'Wargame']
# Merchants & Marauders                                                                                               ['Adventure', 'Fighting', 'Nautical', 'Pirates', 'Transportation']
# Sons of Anarchy: Men of Mayhem                                                                             ['Mafia', 'Movies / TV / Radio theme', 'Negotiation', 'Territory Building']
#
#                                                                                                                                                                                                                                                                                                                 Mechanics  \
# name
# A Game of Thrones: The Board Game (Second Edition)  ['Area Majority / Influence', 'Area Movement', 'Auction/Bidding', 'Auction: Sealed Bid', 'Card Play Conflict Resolution', 'Hand Management', 'Order Counters', 'Player Elimination', "Prisoner's Dilemma", 'Simultaneous Action Selection', 'Variable Player Powers']
# Battlestar Galactica: The Board Game                                                                             ['Area Movement', 'Dice Rolling', 'Hand Management', 'Hidden Roles', 'Once-Per-Game Abilities', 'Role Playing', 'Team-Based Game', 'Traitor Game', 'Variable Player Powers', 'Variable Setup', 'Voting']
# Blood Bowl: Team Manager – The Card Game                                                                                                                                                                ['Area Majority / Influence', 'Card Drafting', 'Deck, Bag, and Pool Building', 'Dice Rolling', 'Hand Management']
# Blood Rage                                                                                                                                                                 ['Action Points', 'Area Majority / Influence', 'Area Movement', 'Card Drafting', 'Hand Management', 'Memory', 'Simultaneous Action Selection']
# Chaos in the Old World                                                                                                                                          ['Action Points', 'Area Majority / Influence', 'Area Movement', 'Dice Rolling', 'Hand Management', 'Role Playing', 'Take That', 'Variable Player Powers']
# Cyclades                                                                                                                                         ['Area Majority / Influence', 'Area Movement', 'Auction/Bidding', 'Auction: Fixed Placement', 'Card Drafting', 'Dice Rolling', 'Set Collection', 'Variable Phase Order']
# Dead of Winter: A Crossroads Game                                     ['Action Points', 'Area Movement', 'Cooperative Game', 'Dice Rolling', 'Hand Management', 'Narrative Choice / Paragraph', 'Push Your Luck', 'Semi-Cooperative Game', 'Storytelling', 'Trading', 'Traitor Game', 'Variable Player Powers', 'Voting']
# Kemet                                                                                                                                                                                ['Action Points', 'Area Majority / Influence', 'Area Movement', 'Card Drafting', 'Card Play Conflict Resolution', 'Hand Management']
# Merchants & Marauders                                                                                                                                                                                         ['Action Points', 'Area Movement', 'Dice Rolling', 'Pick-up and Deliver', 'Race', 'Variable Player Powers']
# Sons of Anarchy: Men of Mayhem                                                                                 ['Action Points', 'Area Majority / Influence', 'Auction/Bidding', 'Commodity Speculation', 'Dice Rolling', 'Modular Board', 'Player Elimination', 'Trading', 'Variable Player Powers', 'Worker Placement']
#
#                                                     Average Rating
# name
# A Game of Thrones: The Board Game (Second Edition)        0.761817
# Battlestar Galactica: The Board Game                      0.774223
# Blood Bowl: Team Manager – The Card Game                  0.738367
# Blood Rage                                                0.800234
# Chaos in the Old World                                    0.767602
# Cyclades                                                  0.752205
# Dead of Winter: A Crossroads Game                         0.759954
# Kemet                                                     0.772289
# Merchants & Marauders                                     0.742219
# Sons of Anarchy: Men of Mayhem                            0.732137
